# %%
# Train the YOLOv8 model with pretrained weight
# !yolo detect train \
data=./data/data_avm.yaml \
model=yolov8x.pt \
epochs=1000 \
imgsz=640 \
project='avm' \
name='pt_aug_fin/train' \
pretrained=True \
patience=100 \
batch=32 \
workers=16

# %%
# Output metrics
# This version only can ouput the metrics for the validation data. 
# By changing the validation path to the training path inside the data.yaml, the metrics for the training dataset can be obtained.
# !yolo detect val \
model='/home/samhong833/DetSegAVM/Detection/yolov8/avm/pt_aug_fin/train/weights/best.pt' \
data='./data/data_avm.yaml' \
project='avm' \
name='results_pt_aug_fin/2_val'

# %%
# Output detection results (jpg and txt files)
# !yolo detect predict \
model='/home/samhong833/DetSegAVM/Detection/yolov8/avm/pt_aug_fin/train/weights/best.pt' \
source='/work/samhong833/Data_AVM/forYOLOv5/images/2_val' \
project='avm' \
name='results_pt_aug_fin/2_val/detect' \
save_txt=true \
save_conf=true

# %% [markdown]
# ![image.png](attachment:image.png)
